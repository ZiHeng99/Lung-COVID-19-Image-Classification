# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd "/content/gdrive/MyDrive/FYP"
# Out:
# /content/gdrive/MyDrive/FYP

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.optim import lr_scheduler

from PIL import Image
from torchsummary import summary

# %% [markdown]
# # Class Radiography Dataset

# %%
class RadiographyDataset(Dataset):

    def __init__(self, root, transform=None):
        super().__init__()
        self.data = []
        self.labels = []
        self.transform = transform
        self.classes   = os.listdir(root)

        #get the training samples
        for class_id, cls in enumerate(self.classes):

          cls_folder = os.path.join(root, cls)

          #get the training samples for the class 'cls'
          for img_name in os.listdir(cls_folder):
            self.data.append(os.path.join(cls_folder, img_name))
            self.labels.append(class_id)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        
        # get the image
        image = Image.open(self.data[idx])
        image = image.convert('RGB')
        
        # perform transformation
        if self.transform is not None:
          image = self.transform(image)
        
        # get the label
        label = self.labels[idx]
        
        return image, label

# %% [markdown]
# # Customizable BLOCK Module

# %%
class BLOCK(nn.Module):

    # ... define the init layer ...
    def __init__(self, blk_cin, blk_cout):

        super().__init__()

        # ... define the convolutional layers ... 
        self.conv1 = nn.Conv2d(blk_cin, blk_cout, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(blk_cout, blk_cout, kernel_size=3, stride=1, padding=1)

    def forward(self, x):

        # ...  forward propagation ... 
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))

        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        
        # ... define block 1 ...
        self.conv_block1 = BLOCK(3, 32)

        # ... define block 2 ...
        self.conv_block2 = BLOCK(32, 64)

        # ... define block 3 ...
        self.conv_block3 = BLOCK(64, 128)

        # ... define block 4 ...
        self.conv_block4 = BLOCK(128, 256)

        self.global_pool = nn.AdaptiveAvgPool2d((1,1))      
        self.fc1         = nn.Linear(256, 10)
        self.fc2         = nn.Linear(10, 3)
        
    def forward(self, x):
        
        # ... block 1 ...
        x = self.conv_block1(x)
        # max pool
        x = F.max_pool2d(x, kernel_size=2, stride=2, padding=0)
        # dropout
        #x = self.dropout(x)
        
        # ... block 2 ...
        x = self.conv_block2(x)
        # max pool
        x = F.max_pool2d(x, kernel_size=2, stride=2, padding=0)
        # dropout
        #x = self.dropout(x)

        # ... block 3 ...
        x = self.conv_block3(x)
        # max pool
        x = F.max_pool2d(x, kernel_size=2, stride=2, padding=0)
        # dropout
        #x = self.dropout(x)

        # ... block 4 ...
        x = self.conv_block4(x)
        # dropout
        #x = self.dropout(x)
        
        # global pool
        x = self.global_pool(x)
        
        # view
        x = x.view(x.size(0), -1) 

        # fc1
        x = self.fc1(x)

        # fc2
        x = self.fc2(x)
        
        return x

# %% [markdown]
# # Train Model

# %%
def train(model, trainloader, valloader, num_epochs, lr=0.01, momentum=0.9, step_size=10, gamma=0.1):
    
    if torch.cuda.is_available():
      device = torch.device("cuda")
      
    else:
      device = torch.device("cpu")
    
    # transfer model to GPU
    model = model.to(device)
    
    # set the optimizer. Use the SGD optimizer. Use the lr and momentum settings passed by the user
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
    scheduler = lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

    # variables
    best_loss = np.inf
    saturate_count = 0
    train_history = []  # save the train loss
    val_history = []    # save the validation loss
    train_acc_history = []  # save the train accuracy
    val_acc_history = []    # save the validation accuracy
    
    # train the network
    for e in range(num_epochs):    

        #running_loss
        running_loss = 0.0
        running_count = 0.0
        running_val_loss = 0.0
        running_val_count = 0.0

        # running_correct
        running_corrects = 0
        running_val_corrects = 0

        #----------------------------train---------------------------------------
        # set to training mode
        model.train()

        # for all batch samples
        for i, (inputs, labels) in enumerate(trainloader):

            # Clear all the gradient to zero
            optimizer.zero_grad()

            # transfer data to GPU
            inputs = inputs.to(device)
            labels = labels.to(device)

            # forward propagation to get h
            outs = model(inputs)

            # compute loss 
            loss = F.cross_entropy(outs, labels)

            # backpropagation to get gradients of all parameters
            loss.backward()

            # update parameters
            optimizer.step()

            # get the loss
            running_loss += loss.item()
            running_count += 1

            # disable gradient computation
            with torch.no_grad():

              # perform inference
              outputs = model(inputs)

              # predict as the best result  
              _, predicted = torch.max(outputs, 1)

              running_corrects += (labels == predicted).double().sum()

        # compute the averaged loss in each epoch
        train_loss = running_loss / running_count
        train_history.append(train_loss)
        running_loss = 0. 
        running_count = 0.  

        # Update the scheduler's counter at the end of each epoch
        scheduler.step()

        # compute the averaged accuracy in each epoch
        train_acc = 100*running_corrects/len(trainloader.dataset)
        train_acc_history.append(train_acc.item())

        #-----------------------validation---------------------------------------
        # set to eval mode
        model.eval()

        for i, (inputs, labels) in enumerate(valloader):

            # transfer data to GPU
            inputs = inputs.to(device)
            labels = labels.to(device)

            # forward propagation to get h
            outs = model(inputs)

            # compute loss 
            loss_val = F.cross_entropy(outs, labels)

            # get the loss
            running_val_loss += loss_val.item()
            running_val_count += 1

            # disable gradient computation
            with torch.no_grad():

              # perform inference
              outputs = model(inputs)

              # predict as the best result  
              _, predicted = torch.max(outputs, 1)

              running_val_corrects += (labels == predicted).double().sum()

        # compute the averaged loss in each epoch
        val_loss = running_val_loss / running_val_count
        val_history.append(val_loss)
        running_val_loss = 0. 
        running_val_count = 0.

        # compute the averaged accuracy in each epoch
        val_acc = 100*running_val_corrects/len(valloader.dataset)
        val_acc_history.append(val_acc.item())

        print(f'Epoch {e+1:2d}/{num_epochs:d} : train_loss = {train_loss:.4f} | val_loss = {val_loss:.4f}' + ' ------- train_acc = {:.2f}%'.format(train_acc) + ' | val_acc = {:.2f}%'.format(val_acc))

        # create save model folder
        if not os.path.exists("./custom_models"):
          os.mkdir("custom_models") 

        # save the model       
        checkpoint_file = './custom_models/saved_model.pt'
        torch.save({
            'epoch': e,
            'loss': train_loss,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
        }, checkpoint_file)       
                
    print("Training completed.")
    return train_history, val_history, train_acc_history, val_acc_history

# %% [markdown]
# # Evaluate Model

# %%
def evaluate(model, testloader):

    # set to evaluation mode
    model.eval() 

    # running_correct
    running_corrects = 0

    acc = 0

    # Repeat for all batch data in the test set
    for inputs, targets in testloader:

        # transfer to the GPU
        if torch.cuda.is_available():
          inputs = inputs.cuda()
          targets = targets.cuda()

        # # disable gradient computation
        with torch.no_grad():
            
            # perform inference
            outputs = model(inputs)

            # predict as the best result  
            _, predicted = torch.max(outputs, 1)

            running_corrects += (targets == predicted).double().sum()
    
    print('Accuracy = {:.2f}%'.format(100*running_corrects/len(testloader.dataset)))

# %% [markdown]
# # Loss graph

# %%
def plot_loss(train_loss, val_loss):
    epochs = range(1, len(train_loss)+1)
    plt.plot(epochs, train_loss, label='train loss')
    plt.plot(epochs, val_loss, label='validation loss')
    plt.ylabel('Loss', fontsize=13)
    plt.xlabel('epochs', fontsize=13)
    plt.title('Loss vs epochs', fontsize=18)
    plt.legend()
    plt.show()

# %% [markdown]
# # Accurarcy graph

# %%
def plot_history_acc(train_acc, val_acc):
    epochs = range(1, len(train_acc)+1)
    plt.figure(figsize=(8, 4))
    plt.plot(epochs, train_acc, color='red', label='train_acc')
    plt.plot(epochs, val_acc, color='blue', label='val_acc')
    plt.ylabel('Accuracy', fontsize=13)
    plt.xlabel('epochs', fontsize=13)
    plt.title('Training vs Validation Accuracy', fontsize=18)
    plt.legend()
    plt.show()

# %% [markdown]
# Check the dataset images number

# %%
classes = ['COVID', 'Normal', 'Viral Pneumonia']

total_ori = 0
ori_path = './COVID-19_Radiography_Dataset/'
for cls in classes:
  total_ori += len(os.listdir(ori_path + cls + '/images'))
print('Total of original datasets         : ', total_ori)
print('---------------------------------------------\n')

print('Train-Covid                        : ', len(os.listdir('./Radiography_Data/train/COVID')))
print('Train-Normal                       : ', len(os.listdir('./Radiography_Data/train/Normal')))
print('Train-Viral Pneumonia              : ', len(os.listdir('./Radiography_Data/train/Viral Pneumonia')))

print('\nValidation-Covid                   : ', len(os.listdir('./Radiography_Data/val/COVID')))
print('Validation-Normal                  : ', len(os.listdir('./Radiography_Data/val/Normal')))
print('Validation-Viral Pneumonia         : ', len(os.listdir('./Radiography_Data/val/Viral Pneumonia')))

print('\nTest-Covid                         : ', len(os.listdir('./Radiography_Data/test/COVID')))
print('Test-Normal                        : ', len(os.listdir('./Radiography_Data/test/Normal')))
print('Test-Viral Pneumonia               : ', len(os.listdir('./Radiography_Data/test/Viral Pneumonia')))

print('---------------------------------------------\n')
new_path = './Radiography_Data/'
folder = ['train', 'val', 'test']
total_new = 0
for fld in folder:
  for cls in classes:
    total_new += len(os.listdir(new_path + fld + '/' + cls))

print('Total of Train, Val, Test datasets : ', total_new)
# Out:
# Total of original datasets         :  15153
# ---------------------------------------------
#
# Train-Covid                        :  2892
# Train-Normal                       :  8153
# Train-Viral Pneumonia              :  1076
#
# Validation-Covid                   :  362
# Validation-Normal                  :  1019
# Validation-Viral Pneumonia         :  134
#
# Test-Covid                         :  362
# Test-Normal                        :  1020
# Test-Viral Pneumonia               :  135
# ---------------------------------------------
#
# Total of Train, Val, Test datasets :  15153

# %% [markdown]
# Show the sample images

# %%
sampleset = RadiographyDataset("./Radiography_Data/train", transform=None)

image_1, label_1 = sampleset[1]
image_2, label_2 = sampleset[2893]
image_3, label_3 = sampleset[11047]

plt.subplot(1, 3, 1)
plt.imshow(image_1)
plt.title('Class =' + sampleset.classes[label_1], fontsize=9)
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(image_2)
plt.title('Class =' + sampleset.classes[label_2], fontsize=9)
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(image_3)
plt.title('Class =' + sampleset.classes[label_3], fontsize=9)
plt.axis('off')

plt.show()

# %% [markdown]
# The network layout

# %%
if torch.cuda.is_available():
  device = torch.device("cuda")
      
else:
  device = torch.device("cpu")
    
sample_net = Net()
sample_net = sample_net.to(device)
summary(sample_net, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 224, 224]             896
#             Conv2d-2         [-1, 32, 224, 224]           9,248
#              BLOCK-3         [-1, 32, 224, 224]               0
#             Conv2d-4         [-1, 64, 112, 112]          18,496
#             Conv2d-5         [-1, 64, 112, 112]          36,928
#              BLOCK-6         [-1, 64, 112, 112]               0
#             Conv2d-7          [-1, 128, 56, 56]          73,856
#             Conv2d-8          [-1, 128, 56, 56]         147,584
#              BLOCK-9          [-1, 128, 56, 56]               0
#            Conv2d-10          [-1, 256, 28, 28]         295,168
#            Conv2d-11          [-1, 256, 28, 28]         590,080
#             BLOCK-12          [-1, 256, 28, 28]               0
# AdaptiveAvgPool2d-13            [-1, 256, 1, 1]               0
#            Linear-14                   [-1, 10]           2,570
#            Linear-15                    [-1, 3]              33
# ================================================================
# Total params: 1,174,859
# Trainable params: 1,174,859
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 68.91
# Params size (MB): 4.48
# Estimated Total Size (MB): 73.96
# ----------------------------------------------------------------

# %%
# !pip install torchview
import torchvision
from torchview import draw_graph

model_graph = draw_graph(sample_net, input_size=(4,3,224,224), expand_nested=True)
model_graph.visual_graph
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchview
#   Downloading torchview-0.2.6-py3-none-any.whl (25 kB)
# Installing collected packages: torchview
# Successfully installed torchview-0.2.6

# %% [markdown]
# # Transformation of Images

# %%
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# transform the model
train_transform = transforms.Compose([
    transforms.Resize(256),                                # output: PIL Image of resolution(256, 256)
    transforms.RandomCrop(224),                            # output: PIL Image of resolution(224, 224)
    transforms.RandomHorizontalFlip(),                     # output: PIL Image of resolution(224, 224)
    transforms.ToTensor(),                                 # output: tensor, dtype = float32, shape = (3, 224, 224), range:[0, 1]
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) # output: same as before except range changes such that mean = 0, std = 1
])

val_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %% [markdown]
# Load the dataset using DataLoader

# %%
#Load the dataset
trainset = RadiographyDataset("./Radiography_Data/train", transform=train_transform)
valset  = RadiographyDataset("./Radiography_Data/val", transform=val_transform)

batch_size = 32
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
valloader  = DataLoader(valset, batch_size=batch_size, shuffle=True, num_workers=2)

# %% [markdown]
# Start training

# %%
# Release Cache
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
net = Net()
train_loss, val_loss, train_acc, val_acc = train (net, trainloader, valloader, num_epochs=100, lr=0.01, momentum=0.9, step_size=30)
# Out:
# Epoch  1/100 : train_loss = 0.8422 | val_loss = 0.8231 ------- train_acc = 66.01% | val_acc = 67.26%
# Epoch  2/100 : train_loss = 0.8245 | val_loss = 0.8266 ------- train_acc = 67.26% | val_acc = 67.26%
# Epoch  3/100 : train_loss = 0.8243 | val_loss = 0.8263 ------- train_acc = 67.26% | val_acc = 67.26%
# Epoch  4/100 : train_loss = 0.8222 | val_loss = 0.8138 ------- train_acc = 67.26% | val_acc = 67.26%
# Epoch  5/100 : train_loss = 0.8010 | val_loss = 0.8002 ------- train_acc = 67.26% | val_acc = 67.26%
# Epoch  6/100 : train_loss = 0.7941 | val_loss = 0.8016 ------- train_acc = 67.26% | val_acc = 67.26%
# Epoch  7/100 : train_loss = 0.7708 | val_loss = 0.7348 ------- train_acc = 67.70% | val_acc = 67.26%
# Epoch  8/100 : train_loss = 0.6794 | val_loss = 0.6288 ------- train_acc = 69.89% | val_acc = 70.50%
# Epoch  9/100 : train_loss = 0.6421 | val_loss = 0.6616 ------- train_acc = 71.20% | val_acc = 69.97%
# Epoch 10/100 : train_loss = 0.6310 | val_loss = 0.6286 ------- train_acc = 71.12% | val_acc = 70.96%
# Epoch 11/100 : train_loss = 0.6085 | val_loss = 0.5903 ------- train_acc = 72.30% | val_acc = 72.21%
# Epoch 12/100 : train_loss = 0.5957 | val_loss = 0.6365 ------- train_acc = 73.48% | val_acc = 70.96%
# Epoch 13/100 : train_loss = 0.5826 | val_loss = 0.5468 ------- train_acc = 74.19% | val_acc = 73.20%
# Epoch 14/100 : train_loss = 0.5507 | val_loss = 0.5725 ------- train_acc = 75.94% | val_acc = 72.74%
# Epoch 15/100 : train_loss = 0.5308 | val_loss = 0.4832 ------- train_acc = 77.88% | val_acc = 79.87%
# Epoch 16/100 : train_loss = 0.5010 | val_loss = 0.5316 ------- train_acc = 79.55% | val_acc = 75.97%
# Epoch 17/100 : train_loss = 0.4731 | val_loss = 0.5276 ------- train_acc = 80.83% | val_acc = 76.63%
# Epoch 18/100 : train_loss = 0.4660 | val_loss = 0.4547 ------- train_acc = 81.44% | val_acc = 81.58%
# Epoch 19/100 : train_loss = 0.4570 | val_loss = 0.4365 ------- train_acc = 82.20% | val_acc = 81.25%
# Epoch 20/100 : train_loss = 0.4289 | val_loss = 0.4110 ------- train_acc = 83.74% | val_acc = 83.56%
# Epoch 21/100 : train_loss = 0.4105 | val_loss = 0.5548 ------- train_acc = 84.27% | val_acc = 76.44%
# Epoch 22/100 : train_loss = 0.4114 | val_loss = 0.3909 ------- train_acc = 84.37% | val_acc = 83.43%
# Epoch 23/100 : train_loss = 0.3879 | val_loss = 0.3983 ------- train_acc = 85.58% | val_acc = 84.22%
# Epoch 24/100 : train_loss = 0.3678 | val_loss = 0.3547 ------- train_acc = 86.57% | val_acc = 85.54%
# Epoch 25/100 : train_loss = 0.3658 | val_loss = 0.3474 ------- train_acc = 86.60% | val_acc = 84.09%
# Epoch 26/100 : train_loss = 0.3308 | val_loss = 0.3028 ------- train_acc = 88.14% | val_acc = 87.85%
# Epoch 27/100 : train_loss = 0.3098 | val_loss = 0.3688 ------- train_acc = 89.15% | val_acc = 86.34%
# Epoch 28/100 : train_loss = 0.2920 | val_loss = 0.2719 ------- train_acc = 89.54% | val_acc = 89.77%
# Epoch 29/100 : train_loss = 0.2804 | val_loss = 0.4859 ------- train_acc = 90.65% | val_acc = 80.86%
# Epoch 30/100 : train_loss = 0.2623 | val_loss = 0.2339 ------- train_acc = 91.42% | val_acc = 90.69%
# Epoch 31/100 : train_loss = 0.1873 | val_loss = 0.1962 ------- train_acc = 92.98% | val_acc = 92.87%
# Epoch 32/100 : train_loss = 0.1693 | val_loss = 0.1779 ------- train_acc = 93.81% | val_acc = 93.33%
# Epoch 33/100 : train_loss = 0.1638 | val_loss = 0.2005 ------- train_acc = 94.19% | val_acc = 92.48%
# Epoch 34/100 : train_loss = 0.1636 | val_loss = 0.2113 ------- train_acc = 94.00% | val_acc = 91.55%
# Epoch 35/100 : train_loss = 0.1606 | val_loss = 0.1770 ------- train_acc = 94.26% | val_acc = 92.74%
# Epoch 36/100 : train_loss = 0.1549 | val_loss = 0.2045 ------- train_acc = 94.22% | val_acc = 92.28%
# Epoch 37/100 : train_loss = 0.1536 | val_loss = 0.1660 ------- train_acc = 94.42% | val_acc = 94.39%
# Epoch 38/100 : train_loss = 0.1491 | val_loss = 0.1777 ------- train_acc = 94.69% | val_acc = 93.40%
# Epoch 39/100 : train_loss = 0.1448 | val_loss = 0.1957 ------- train_acc = 94.86% | val_acc = 92.48%
# Epoch 40/100 : train_loss = 0.1416 | val_loss = 0.1823 ------- train_acc = 94.96% | val_acc = 93.00%
# Epoch 41/100 : train_loss = 0.1392 | val_loss = 0.1407 ------- train_acc = 95.10% | val_acc = 94.72%
# Epoch 42/100 : train_loss = 0.1394 | val_loss = 0.1521 ------- train_acc = 95.02% | val_acc = 93.99%
# Epoch 43/100 : train_loss = 0.1350 | val_loss = 0.1405 ------- train_acc = 95.14% | val_acc = 94.92%
# Epoch 44/100 : train_loss = 0.1330 | val_loss = 0.2046 ------- train_acc = 95.22% | val_acc = 92.34%
# Epoch 45/100 : train_loss = 0.1328 | val_loss = 0.1381 ------- train_acc = 95.42% | val_acc = 95.45%
# Epoch 46/100 : train_loss = 0.1301 | val_loss = 0.1309 ------- train_acc = 95.51% | val_acc = 95.05%
# Epoch 47/100 : train_loss = 0.1350 | val_loss = 0.1759 ------- train_acc = 95.26% | val_acc = 93.00%
# Epoch 48/100 : train_loss = 0.1240 | val_loss = 0.1357 ------- train_acc = 95.82% | val_acc = 95.12%
# Epoch 49/100 : train_loss = 0.1258 | val_loss = 0.1295 ------- train_acc = 95.78% | val_acc = 95.25%
# Epoch 50/100 : train_loss = 0.1224 | val_loss = 0.1519 ------- train_acc = 95.65% | val_acc = 94.32%
# Epoch 51/100 : train_loss = 0.1162 | val_loss = 0.1308 ------- train_acc = 96.14% | val_acc = 95.38%
# Epoch 52/100 : train_loss = 0.1233 | val_loss = 0.1358 ------- train_acc = 95.74% | val_acc = 94.92%
# Epoch 53/100 : train_loss = 0.1186 | val_loss = 0.1375 ------- train_acc = 95.99% | val_acc = 94.72%
# Epoch 54/100 : train_loss = 0.1187 | val_loss = 0.1400 ------- train_acc = 95.89% | val_acc = 95.25%
# Epoch 55/100 : train_loss = 0.1099 | val_loss = 0.1511 ------- train_acc = 96.28% | val_acc = 93.93%
# Epoch 56/100 : train_loss = 0.1089 | val_loss = 0.1444 ------- train_acc = 96.29% | val_acc = 94.92%
# Epoch 57/100 : train_loss = 0.1128 | val_loss = 0.2097 ------- train_acc = 96.10% | val_acc = 91.02%
# Epoch 58/100 : train_loss = 0.1087 | val_loss = 0.1318 ------- train_acc = 96.39% | val_acc = 94.98%
# Epoch 59/100 : train_loss = 0.1081 | val_loss = 0.1395 ------- train_acc = 96.50% | val_acc = 95.05%
# Epoch 60/100 : train_loss = 0.1061 | val_loss = 0.1324 ------- train_acc = 96.44% | val_acc = 95.05%
# Epoch 61/100 : train_loss = 0.0904 | val_loss = 0.1206 ------- train_acc = 97.01% | val_acc = 95.97%
# Epoch 62/100 : train_loss = 0.0877 | val_loss = 0.1218 ------- train_acc = 97.07% | val_acc = 95.71%
# Epoch 63/100 : train_loss = 0.0854 | val_loss = 0.1185 ------- train_acc = 96.91% | val_acc = 96.04%
# Epoch 64/100 : train_loss = 0.0896 | val_loss = 0.1180 ------- train_acc = 97.02% | val_acc = 95.97%
# Epoch 65/100 : train_loss = 0.0841 | val_loss = 0.1355 ------- train_acc = 97.10% | val_acc = 94.92%
# Epoch 66/100 : train_loss = 0.0911 | val_loss = 0.1132 ------- train_acc = 96.85% | val_acc = 95.84%
# Epoch 67/100 : train_loss = 0.0846 | val_loss = 0.1289 ------- train_acc = 97.03% | val_acc = 95.05%
# Epoch 68/100 : train_loss = 0.0817 | val_loss = 0.1151 ------- train_acc = 97.20% | val_acc = 96.37%
# Epoch 69/100 : train_loss = 0.0813 | val_loss = 0.1185 ------- train_acc = 97.20% | val_acc = 95.58%
# Epoch 70/100 : train_loss = 0.0853 | val_loss = 0.1184 ------- train_acc = 97.01% | val_acc = 95.64%
# Epoch 71/100 : train_loss = 0.0840 | val_loss = 0.1195 ------- train_acc = 97.19% | val_acc = 95.51%
# Epoch 72/100 : train_loss = 0.0829 | val_loss = 0.1147 ------- train_acc = 97.29% | val_acc = 96.17%
# Epoch 73/100 : train_loss = 0.0833 | val_loss = 0.1187 ------- train_acc = 97.07% | val_acc = 95.58%
# Epoch 74/100 : train_loss = 0.0818 | val_loss = 0.1110 ------- train_acc = 97.19% | val_acc = 96.04%
# Epoch 75/100 : train_loss = 0.0828 | val_loss = 0.1141 ------- train_acc = 97.18% | val_acc = 95.71%
# Epoch 76/100 : train_loss = 0.0820 | val_loss = 0.1155 ------- train_acc = 97.19% | val_acc = 95.78%
# Epoch 77/100 : train_loss = 0.0806 | val_loss = 0.1151 ------- train_acc = 97.05% | val_acc = 95.91%
# Epoch 78/100 : train_loss = 0.0816 | val_loss = 0.1166 ------- train_acc = 97.14% | val_acc = 96.04%
# Epoch 79/100 : train_loss = 0.0774 | val_loss = 0.1095 ------- train_acc = 97.38% | val_acc = 96.04%
# Epoch 80/100 : train_loss = 0.0799 | val_loss = 0.1143 ------- train_acc = 97.25% | val_acc = 95.91%
# Epoch 81/100 : train_loss = 0.0799 | val_loss = 0.1134 ------- train_acc = 97.25% | val_acc = 95.97%
# Epoch 82/100 : train_loss = 0.0817 | val_loss = 0.1180 ------- train_acc = 97.18% | val_acc = 95.78%
# Epoch 83/100 : train_loss = 0.0802 | val_loss = 0.1192 ------- train_acc = 97.17% | val_acc = 95.31%
# Epoch 84/100 : train_loss = 0.0795 | val_loss = 0.1176 ------- train_acc = 97.14% | val_acc = 95.45%
# Epoch 85/100 : train_loss = 0.0819 | val_loss = 0.1121 ------- train_acc = 97.19% | val_acc = 95.84%
# Epoch 86/100 : train_loss = 0.0779 | val_loss = 0.1236 ------- train_acc = 97.35% | val_acc = 94.98%
# Epoch 87/100 : train_loss = 0.0792 | val_loss = 0.1166 ------- train_acc = 97.30% | val_acc = 95.78%
# Epoch 88/100 : train_loss = 0.0812 | val_loss = 0.1209 ------- train_acc = 97.06% | val_acc = 95.58%
# Epoch 89/100 : train_loss = 0.0783 | val_loss = 0.1081 ------- train_acc = 97.32% | val_acc = 96.24%
# Epoch 90/100 : train_loss = 0.0741 | val_loss = 0.1101 ------- train_acc = 97.50% | val_acc = 95.97%
# Epoch 91/100 : train_loss = 0.0780 | val_loss = 0.1167 ------- train_acc = 96.99% | val_acc = 95.84%
# Epoch 92/100 : train_loss = 0.0743 | val_loss = 0.1108 ------- train_acc = 97.38% | val_acc = 95.91%
# Epoch 93/100 : train_loss = 0.0764 | val_loss = 0.1168 ------- train_acc = 97.37% | val_acc = 95.64%
# Epoch 94/100 : train_loss = 0.0775 | val_loss = 0.1134 ------- train_acc = 97.43% | val_acc = 95.64%
# Epoch 95/100 : train_loss = 0.0744 | val_loss = 0.1121 ------- train_acc = 97.25% | val_acc = 95.84%
# Epoch 96/100 : train_loss = 0.0766 | val_loss = 0.1108 ------- train_acc = 97.48% | val_acc = 95.91%
# Epoch 97/100 : train_loss = 0.0743 | val_loss = 0.1124 ------- train_acc = 97.47% | val_acc = 95.78%
# Epoch 98/100 : train_loss = 0.0776 | val_loss = 0.1141 ------- train_acc = 97.32% | val_acc = 95.64%
# Epoch 99/100 : train_loss = 0.0768 | val_loss = 0.1122 ------- train_acc = 97.34% | val_acc = 95.78%
# Epoch 100/100 : train_loss = 0.0757 | val_loss = 0.1096 ------- train_acc = 97.30% | val_acc = 96.11%
# Training completed.

# %%
plot_loss(train_loss, val_loss)

# %%
plot_history_acc(train_acc, val_acc)

# %% [markdown]
# Evaluate model

# %%
# transform the model
test_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

batch_size = 32
testset = RadiographyDataset("./Radiography_Data/test", transform=test_transform)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=True, num_workers=2)

# %%
evaluate(net, testloader)
# Out:
# Accuracy = 96.37%
